# %% [markdown]
# # CSP Debugging & Systems Playground (Lab Notebook)
#
# **Purpose:** This notebook is my personal “systems + debugging gym.”
# I use it to (1) record failures and fixes, (2) practice small targeted drills, and (3) build intuition for memory, performance, and program behavior.
#
# ---
#
# ## How I use this notebook (rules)
# - **Small experiments only** (5–30 min each). No huge projects.
# - Every experiment must end with a **Takeaway** and **Next time** note.
# - If something breaks, I write the **exact error** + **root cause** + **how I confirmed**.
#
# ---
#
# ## Section A — Weekly goals (update every week)
# ### Week of: ________
# - **Concept focus:** (e.g., pointers + dynamic memory)
# - **Tool focus:** (e.g., gdb / sanitizers / valgrind)
# - **Output:** (e.g., 5 drills + 2 bug writeups)
