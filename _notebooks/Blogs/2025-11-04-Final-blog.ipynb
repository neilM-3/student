# %% [markdown]
# ---
# layout: post
# title: Final Blog CSP Assignment Review With Mort
# permalink: /blogs/final-blog-csp
# author: Neil Manjrekar
# description: My retrospective on growth, projects, and learning throughout CSP this year.
# ---

# %% [markdown]
# <button class="theme-toggle" onclick="toggleTheme()">🌙 Dark Mode</button>
#
# <script>
# // Check for saved theme preference or default to light
# const currentTheme = localStorage.getItem('theme') || 'light';
# document.documentElement.setAttribute('data-theme', currentTheme);
# updateButtonText();
#
# function toggleTheme() {
#     const theme = document.documentElement.getAttribute('data-theme');
#     const newTheme = theme === 'light' ? 'dark' : 'light';
#
#     document.documentElement.setAttribute('data-theme', newTheme);
#     localStorage.setItem('theme', newTheme);
#     updateButtonText();
# }
#
# function updateButtonText() {
#     const theme = document.documentElement.getAttribute('data-theme');
#     const button = document.querySelector('.theme-toggle');
#     if (button) {
#         button.textContent = theme === 'light' ? '🌙 Dark Mode' : '☀️ Light Mode';
#     }
# }
# </script>
# # Final Blog CSP Assignment Review With Mort
#
# ## 1. How Much I Have Grown Since The Start of The Year
#
# ### Beginning of Year (August/September):
# - I barely knew how to code. Python was confusing and I struggled with basic syntax
# - I didn't understand how websites worked or how HTML/CSS connected
# - I was nervous about coding projects and needed a lot of help
# - I wasn't confident presenting my work
#
# ### Now (November):
# - I can build functional programs in Python and understand loops, functions, and data structures
# - I created my Digital Famine project with working features
# - I understand frontend and backend development
# - I'm more confident debugging my own code and helping classmates
# - I can present my technical work clearly
#
# **Growth:** From being scared to code to building real projects independently!
#
# ---
#
# ## 2. Remember Key Things From 3 Sprints
#
# ### Sprint 1 - Tools:
# - Learned how to use GitHub for version control and collaboration
# - Set up VSCode and Jupyter notebooks for development
# - Understood how to push/pull code and work with repositories
#
# ### Sprint 2 - Fundamentals of JavaScript/Python:
# - Mastered Python basics: variables, loops, conditionals, functions
# - Learned JavaScript for interactive web pages
# - Built interactive features using both languages
#
# ### Sprint 3 - West Coast Travel or Digital Famine:
# - Created a full-stack web application
# - Worked with Flask, APIs, and databases
# - Collaborated with my team to integrate different parts
#
# ---
#
# ## 3. How N@tM Went
#
# ### My Experience:
# - I presented my Digital Famine project and explained the features
# - I was nervous but felt proud showing what I built
# - Many people visited my station
#
# ### Favorite Comments:
# - "Your project is really impressive!" - Made me feel proud of my work
# - "I like how everything connects together" - Showed that my technical planning worked
# - People were especially impressed by the backend functionality
#
# ---
#
# ## 4. What I Want to Do Next on Project
#
# ### Improvements I'd Make:
# - Add user authentication system for personalized accounts
# - Improve the UI/UX design to be more modern and polished
# - Fix bugs with data persistence
# - Add mobile responsive design
#
# ### New Features:
# - Real-time notifications
# - Social sharing capabilities
# - Analytics dashboard
#
# ---
#
# ## 5. What I Want to Learn Next in CompSci
#
# **Technical Skills:**
# - React or Vue.js for better frontend frameworks
# - Advanced database management with SQL
# - API integration and third-party services
# - Machine learning basics
#
# **Concepts:**
# - Cybersecurity fundamentals
# - Cloud deployment (AWS, Azure)
# - Mobile app development
# - Algorithms and data structures for AP exam
#
# ---
#
# ## 6. Analytics Review
#
# **My Blog Statistics:**
# - Total views: 150+
# - Most popular post: Snake Game Tutorial
# - Peak traffic: During N@tM week
# - Engagement rate: Growing steadily
#
# ---
#
# ## 7. MCQ Review, Score, Correction, and Approach
#
# **My Score:** 45/66
#
# **What Went Well:**
# - Strong in loops and conditionals
# - Understood list and array manipulation
# - Good at logic problems
#
# **What I Struggled With:**
# - Binary/hexadecimal conversions
# - Algorithm efficiency questions
# - Some abstraction concepts
#
# **Corrections:**
# - Question 12: Misunderstood how recursion works in the given example
# - Question 27: Confused iteration vs traversal
# - Question 35: Need to review boolean logic operators
#
# **My Approach Going Forward:**
# - Practice 5 MCQ questions daily
# - Review CollegeBoard study materials weekly
# - Work on weak areas systematically
#
# ---
#
# ## 8. Something Cool I'd Like to Share
#
# ### My Coolest Achievement:
# Successfully implemented a working backend API that handles user data and connects to our frontend! This was challenging because I had to learn about routing, databases, and authentication all at once.
#
# ### Why It's Cool:
# It taught me how real web applications work behind the scenes. I now understand what happens when I log into websites or save data.
#
# ### What This Taught Me:
# Persistence pays off! I spent hours debugging, but the feeling when it finally worked was incredible. I learned that being a developer means being comfortable with not knowing everything and learning as you go.
#
# ---
#
# ## Conclusion
#
# This trimester has been an incredible journey of growth. I went from barely understanding Python syntax to building full-stack web applications. I'm excited to continue learning and building even more complex projects. Thanks to Mr. Mortensen and my classmates for an amazing experience!
#
# **Ready for Trimester 2!**

# %% [markdown]
# ## Cool Background for this Blog

# %%
from IPython.display import HTML

HTML("""<style>
.jp-Notebook {
    background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
    padding: 30px;
    border-radius: 15px;
    box-shadow: 0 10px 30px rgba(0,0,0,0.3);
}
.jp-Cell {
    background: rgba(255, 255, 255, 0.95);
    border-radius: 10px;
    padding: 20px;
    margin: 15px 0;
    box-shadow: 0 4px 6px rgba(0,0,0,0.1);
}
.jp-Cell:hover {
    transform: translateY(-2px);
    box-shadow: 0 6px 12px rgba(0,0,0,0.15);
    transition: all 0.2s ease;
}
.jp-MarkdownOutput h1, .jp-MarkdownOutput h2, .jp-MarkdownOutput h3 {
    color: #667eea;
    text-shadow: 2px 2px 4px rgba(0,0,0,0.1);
}
</style>""");
